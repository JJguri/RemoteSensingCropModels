# %%
#Required packages
import pandas as pd
import numpy as np

# %%
#Loading the original climate dataset
df=pd.read_csv(r'C:\Users\jjojeda\Google Drive\COALAR\Sorgo\Python\df1.csv')
df.columns
# Out:
# Index(['SimulationName', 'Date', 'AGGR_S2_mean', 'AGGR_S2_max', 'AGGR_S2_min'], dtype='object')

# %%
df.index=pd.to_datetime(df.Date,format='%Y-%m')
df

# %%
df
# Out:
#                   SimulationName   AGGR_S2_mean  AGGR_S2_max  AGGR_S2_min
# Date
# 2018-12-15  380074_Che8_sna_19_F           1.09         1.64         0.75
# 2018-12-16  380074_Che8_sna_19_F                         NaN          NaN
# 2018-12-17  380074_Che8_sna_19_F                         NaN          NaN
# 2018-12-18  380074_Che8_sna_19_F                         NaN          NaN
# 2018-12-19  380074_Che8_sna_19_F                         NaN          NaN
# ...                          ...            ...          ...          ...
# 2019-03-05  460100_LLo0_des_19_F                         NaN          NaN
# 2019-03-06  460100_LLo0_des_19_F                         NaN          NaN
# 2019-03-07  460100_LLo0_des_19_F                         NaN          NaN
# 2019-03-08  460100_LLo0_des_19_F                         NaN          NaN
# 2019-03-09  460100_LLo0_des_19_F                         NaN          NaN
#
# [1923 rows x 4 columns]

# %%
df = df.resample('D').fillna(None)
df['SimulationName']=df.iloc[0,0]
df=df.drop(['name','Date'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-48013042e41c> in <module>
# ----> 1 df = df.resample('D').fillna(None)
#       2 #df['SimulationName']=df.iloc[0,0]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\resample.py in fillna(self, method, limit)
#     766         2018-01-01 02:00:00  6.0  5
#     767         """
# --> 768         return self._upsample(method, limit=limit)
#     769
#     770     @Appender(_shared_docs["interpolate"] % _shared_docs_kwargs)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\resample.py in _upsample(self, method, limit, fill_value)
#    1123         else:
#    1124             result = obj.reindex(
# -> 1125                 res_index, method=method, limit=limit, fill_value=fill_value
#    1126             )
#    1127
#
# ...

# %%
df
# Out:
#             Leaf.CoverGreen  Leaf.CoverGreenError  Leaf.CoverTotal  \
# Date
# 2018-12-15             0.08                  0.01             0.08
# 2018-12-16              NaN                   NaN              NaN
# 2018-12-17              NaN                   NaN              NaN
# 2018-12-18              NaN                   NaN              NaN
# 2018-12-19              NaN                   NaN              NaN
# ...                     ...                   ...              ...
# 2019-05-20              NaN                   NaN              NaN
# 2019-05-21              NaN                   NaN              NaN
# 2019-05-22              NaN                   NaN              NaN
# 2019-05-23              NaN                   NaN              NaN
# 2019-05-24             0.05                  0.00             0.05
#
#             Leaf.CoverTotalError  RadInt  RadIntError  AGGR  AGGRError  NDVI  \
# Date
# ...

# %%
#Using interpolate function to fill gaps of any size with a straight line
#Remember to change the name of the climate variables if you need
for columns in df[['AGGR']]: 
    df[columns].interpolate(method='linear', inplace=True)

# %%
df
# Out:
#             Leaf.CoverGreen  Leaf.CoverGreenError  Leaf.CoverTotal  \
# Date
# 2018-12-15             0.08                  0.01             0.08
# 2018-12-16              NaN                   NaN              NaN
# 2018-12-17              NaN                   NaN              NaN
# 2018-12-18              NaN                   NaN              NaN
# 2018-12-19              NaN                   NaN              NaN
# ...                     ...                   ...              ...
# 2019-05-20              NaN                   NaN              NaN
# 2019-05-21              NaN                   NaN              NaN
# 2019-05-22              NaN                   NaN              NaN
# 2019-05-23              NaN                   NaN              NaN
# 2019-05-24             0.05                  0.00             0.05
#
#             Leaf.CoverTotalError  RadInt  RadIntError   AGGR  AGGRError  NDVI  \
# Date
# ...

# %%
df.to_csv(r'C:\Users\jjojeda\Google Drive\COALAR\Sorgo\Python\AA.csv')
